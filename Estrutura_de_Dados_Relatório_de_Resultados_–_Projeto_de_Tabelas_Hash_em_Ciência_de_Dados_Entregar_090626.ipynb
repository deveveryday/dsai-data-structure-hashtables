# %% [markdown]
# ## Importando bibliotecas e carregando Datasets

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

from google.colab import drive
drive.mount("/content/drive")

path = "/content/drive/MyDrive/cdai/ColabNotebooks/xls/"

df_clientes_transacoes = pd.read_excel(path + "dataset_clientes_transacoes.xlsx")
df_produtos = pd.read_excel(path + "dataset_produtos.xlsx")
df_texto = pd.read_excel(path + "dataset_texto.xlsx")
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1224 entries, 0 to 1223
# Data columns (total 4 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   cpf             1224 non-null   int64
#  1   nome            1224 non-null   object
#  2   data_transacao  1224 non-null   datetime64[ns]
#  3   valor           1224 non-null   float64
# dtypes: datetime64[ns](1), float64(1), int64(1), object(1)
# memory usage: 38.4+ KB
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1230 entries, 0 to 1229
# Data columns (total 4 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   id_produto  1230 non-null   int64
#  1   nome        1230 non-null   object
#  2   categoria   1230 non-null   object
#  3   preco       1230 non-null   float64
# dtypes: float64(1), int64(1), object(2)
# memory usage: 38.6+ KB
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1240 entries, 0 to 1239
# Data columns (total 1 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   frase   1240 non-null   object
# dtypes: object(1)
# memory usage: 9.8+ KB
# cliente 1200
# produto 6
# texto 6

# %% [markdown]
# # Análise Exploratória

# %%
#cpf nome data_transacao valor
df_clientes_transacoes.info()
# 1230 registros
# 1200 cpf únicos

#id_produto nome categoria   preco
df_produtos.info()
# 1240 observações
# 6 nomes únicos

#frase
df_texto.info()
# 1240 registros
# 6 frases únicas


print("cliente", df_clientes_transacoes['cpf'].nunique())
print("produto", df_produtos['nome'].nunique())
print("texto", df_texto['frase'].nunique())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1224 entries, 0 to 1223
# Data columns (total 4 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   cpf             1224 non-null   int64
#  1   nome            1224 non-null   object
#  2   data_transacao  1224 non-null   datetime64[ns]
#  3   valor           1224 non-null   float64
# dtypes: datetime64[ns](1), float64(1), int64(1), object(1)
# memory usage: 38.4+ KB
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1230 entries, 0 to 1229
# Data columns (total 4 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   id_produto  1230 non-null   int64
#  1   nome        1230 non-null   object
#  2   categoria   1230 non-null   object
#  3   preco       1230 non-null   float64
# dtypes: float64(1), int64(1), object(2)
# memory usage: 38.6+ KB
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1240 entries, 0 to 1239
# Data columns (total 1 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   frase   1240 non-null   object
# dtypes: object(1)
# memory usage: 9.8+ KB
# cliente 1200
# produto 6
# texto 6
# <class 'pandas.core.frame.DataFrame'>
# Index: 1200 entries, 0 to 1229
# Data columns (total 4 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   id_produto  1200 non-null   int64
#  1   nome        1200 non-null   object
#  2   categoria   1200 non-null   object
#  3   preco       1200 non-null   float64
# dtypes: float64(1), int64(1), object(2)
# memory usage: 46.9+ KB
# duuu ['Notebook' 'Relógio' 'Fone' 'Camisa' 'Celular' 'Tênis']

# %% [markdown]
# # Removendo duplicados

# %%
df_clientes_clean = df_clientes_transacoes.drop_duplicates().copy()
df_produtos_clean = df_produtos.drop_duplicates().copy()
df_texto_clean = df_texto.drop_duplicates().copy()

df_clientes_clean.info()
df_produtos_clean.info()
df_texto_clean.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 1200 entries, 0 to 1223
# Data columns (total 4 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   cpf             1200 non-null   int64
#  1   nome            1200 non-null   object
#  2   data_transacao  1200 non-null   datetime64[ns]
#  3   valor           1200 non-null   float64
# dtypes: datetime64[ns](1), float64(1), int64(1), object(1)
# memory usage: 46.9+ KB
# <class 'pandas.core.frame.DataFrame'>
# Index: 1200 entries, 0 to 1229
# Data columns (total 4 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   id_produto  1200 non-null   int64
#  1   nome        1200 non-null   object
#  2   categoria   1200 non-null   object
#  3   preco       1200 non-null   float64
# dtypes: float64(1), int64(1), object(2)
# memory usage: 46.9+ KB
# <class 'pandas.core.frame.DataFrame'>
# Index: 6 entries, 0 to 20
# Data columns (total 1 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   frase   6 non-null      object
# dtypes: object(1)
# memory usage: 96.0+ bytes

# %%
my_list = [None, None, None, None, None, None, None, None, None, None]
products = [None, None, None, None, None, None]


def hash_function(value):
  sum_of_chars = 0
  for char in value:
    sum_of_chars += ord(char)

  return sum_of_chars % 10


def add(name):
  index = hash_function(name)
  my_list[index] = name


def contains(name):
  index = hash_function(name)
  return my_list[index] == name


def add_product(name):
  index = hash_function(name)
  my_list[index] = name


def contains_product(name):
  index = hash_function(name)
  return my_list[index] == name


print(my_list)
# Out:
# [None, None, None, None, None, 'Ann', None, None, None, None]

# %%
#collisions

my_list = [
  [],
  [],
  [],
  [],
  [],
  [],
  [],
  [],
  [],
  []
]


add('Lisa')
add('Siri')

print(my_list)
